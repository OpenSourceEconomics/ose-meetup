# %% [markdown]
# The params_df in this example is completely made up. I use it as abstract test case in estimagic. At the bottom you can see which types of constraints are already implemented.

# %%
import pandas as pd
import numpy as np

# %%
params = pd.read_csv('reparametrize_fixtures.csv').set_index(
    ['category', 'subcategory', 'name'])
params['value'] = params['value0']
params = params[['value', 'lower', 'upper', 'fixed']]
params
# Out:
#                            value  lower  upper  fixed
# category subcategory name
# a        a           0       0.1    NaN    NaN   True
#                      1       0.2    NaN    NaN  False
#                      2       0.3    NaN    NaN   True
#                      3       0.4    NaN    NaN  False
#                      4       0.5    NaN    NaN   True
# b        b           0      10.3   -5.0   15.0  False
#                      1      18.7  -10.0   20.0  False
#                      2      -5.2  -10.0    NaN  False
#                      3       3.2    NaN   20.0  False
# c        c1          0       0.5    NaN    NaN  False
#                      1       0.7    NaN    NaN  False
#          c2          0       0.1    NaN    NaN  False
#                      1       0.2    NaN    NaN  False
#                      2       0.2    NaN    NaN  False
#                      3       0.5    NaN    NaN  False
# d        d           k       1.0    NaN    NaN  False
# ...

# %%
constr = [
        {"loc": ("c", "c2"), "type": "probability"},
        {"loc": "d", "type": "increasing"},
        {"loc": "e", "type": "covariance"},
        {"loc": "f", "type": "covariance"},
        {"loc": "g", "type": "sum", "value": 5},
        {"loc": "h", "type": "equality"},
        {"loc": "i", "type": "equality"},
        {"query": 'subcategory == "j1" | subcategory == "i1"', "type": "equality"},
    ]

# %%
# params.loc[("c", "c2")]

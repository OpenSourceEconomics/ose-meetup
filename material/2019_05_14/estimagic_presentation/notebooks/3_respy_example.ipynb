# %% [markdown]
# This is just an example of how a params_df can look in practice and how estimagic can help to parse the parameter vector more efficiently. You don't have to understand the details of the respy model.

# %%
import pandas as pd
from estimagic.optimization.utilities import cov_params_to_matrix

# %%
params_df = pd.read_csv('kw_data_one.csv').set_index(['category', 'name'])
params_df
# Out:
#                                       value  fixed  lower  upper  \
# category      name
# delta         delta                  0.9500  False    0.7    1.0
# coeffs_common return_hs_degree       0.0000  False    NaN    NaN
#               return_col_degree      0.0000  False    NaN    NaN
# coeffs_a      skill_price            9.2100  False    NaN    NaN
#               return_schooling       0.0380  False    NaN    NaN
#               exp_a                  0.0330  False    NaN    NaN
#               exp_a_square          -0.0005  False    NaN    NaN
#               exp_b                  0.0000  False    NaN    NaN
#               exp_b_square           0.0000  False    NaN    NaN
#               premium_hs             0.0000  False    NaN    NaN
#               premium_col            0.0000  False    NaN    NaN
#               age                    0.0000  False    NaN    NaN
#               minor                  0.0000  False    NaN    NaN
# ...

# %%
constraints = [{'loc': 'shocks', 'type': 'covariance'}]

# %%
shock_coeffs = cov_params_to_matrix(params_df.loc['shocks', 'value'].to_numpy())

# %%
shock_coeffs
# Out:
# array([[2.0e-01, 0.0e+00, 0.0e+00, 0.0e+00],
#        [0.0e+00, 2.5e-01, 0.0e+00, 0.0e+00],
#        [0.0e+00, 0.0e+00, 1.5e+03, 0.0e+00],
#        [0.0e+00, 0.0e+00, 0.0e+00, 1.5e+03]])
